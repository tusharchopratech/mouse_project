# %%
import pandas as pd
import io
import numpy as np
from scipy.signal import butter, lfilter
import matplotlib.pyplot as plt
import os

# %%
def butter_bandpass(lowcut, highcut, fs, order=4):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def butter_bandpass_filter(data,  lowcut=110, highcut=250, fs=2048, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
folder = "C:/Users/tushar/Desktop/gamingtech/wearablecode/windows/debug/dataset/erik_data/"
df = pd.read_csv(folder+"data_Erik01_C3.txt", sep=" ", header=None)

# %%
data = df.values
data.shape
# Out:
# (65100, 7)

# %%
fig= plt.figure(figsize=(50,10))
plt.plot(data[:,0], label='CH 1') 
plt.plot(data[:,4], label='Left') 
plt.legend()
plt.show()

# %%
fig= plt.figure(figsize=(50,10))
plt.plot(np.abs(data[:,0])**3, label='CH 1') 
plt.plot(data[:,4], label='Left') 
plt.legend()
plt.show()

# %%
fig= plt.figure(figsize=(50,10))
ch1data = butter_bandpass_filter(data[:,0], 110,250,2048,5)
plt.plot(ch1data**3, label='CH 1') 
plt.plot(data[:,4], label='Left') 
plt.legend()
plt.show()

# %%
fig= plt.figure(figsize=(30,7))
ch1data = butter_bandpass_filter(data[:,0], 110,250,2048,5)
plt.plot(ch1data**3, label='CH 1') 
plt.plot(data[:,4], label='Left') 
plt.ylim([-0.8, 5])
plt.legend()
plt.show()

fig= plt.figure(figsize=(30,7))
ch1data = butter_bandpass_filter(data[:,0]**3, 110,250,2048,5)
plt.plot(ch1data, label='CH 1') 
plt.plot(data[:,4], label='Left') 
plt.ylim([-0.8, 5])
plt.legend()
plt.show()




fig= plt.figure(figsize=(30,5))
ch2data = butter_bandpass_filter(data[:,1], 110,250,2048)
plt.plot(ch2data**3, label='CH 2') 
plt.plot(data[:,4], label='Left') 
plt.legend()
plt.ylim([-0.8, 0.5])
plt.show()


fig= plt.figure(figsize=(30,7))
plt.plot(data[0:,0]**3, label='CH 1') 
plt.plot(data[0:,5]**3, label='Right') 
plt.ylim([-0.8, 2])
plt.legend()
plt.show()

fig= plt.figure(figsize=(30,5))
plt.plot(data[0:,1]**3, label='CH 2') 
plt.plot(data[0:,5]**3, label='Right') 
plt.legend()
plt.ylim([-0.8, 2])
plt.show()








fig= plt.figure(figsize=(30,7))
plt.plot(df[1], label='CH 2') 
plt.plot(df[4], label='Left') 
plt.plot(df[5], label='Right') 
plt.plot(df[6], label='Thumb') 
plt.legend()
plt.show()


fig= plt.figure(figsize=(30,7))
plt.plot(df[2], label='CH 3') 
plt.plot(df[4], label='Left') 
plt.plot(df[5], label='Right') 
plt.plot(df[6], label='Thumb') 
plt.legend()
plt.show()

fig= plt.figure(figsize=(30,7))
plt.plot(df[3], label='CH 4') 
plt.plot(df[4], label='Left') 
plt.plot(df[5], label='Right') 
plt.plot(df[6], label='Thumb') 
plt.legend()
plt.show()
# Out:
# c:\python37\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
uploaded = files.upload()
df = pd.read_csv(io.BytesIO(uploaded['data_test.txt']), sep=" ", header=None)
import matplotlib.pyplot as plt
fig= plt.figure(figsize=(30,7))
plt.plot(df[0], label='CH 1') 
plt.plot(df[4], label='Left') 
plt.plot(df[5], label='Right') 
plt.plot(df[6], label='Thumb') 
plt.legend()
plt.show()


fig= plt.figure(figsize=(30,7))
plt.plot(df[1], label='CH 2') 
plt.plot(df[4], label='Left') 
plt.plot(df[5], label='Right') 
plt.plot(df[6], label='Thumb') 
plt.legend()
plt.show()


fig= plt.figure(figsize=(30,7))
plt.plot(df[2], label='CH 3') 
plt.plot(df[4], label='Left') 
plt.plot(df[5], label='Right') 
plt.plot(df[6], label='Thumb') 
plt.legend()
plt.show()

fig= plt.figure(figsize=(30,7))
plt.plot(df[3], label='CH 4') 
plt.plot(df[4], label='Left') 
plt.plot(df[5], label='Right') 
plt.plot(df[6], label='Thumb') 
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-eda4825eb2a9> in <module>
# ----> 1 uploaded = files.upload()
#       2 df = pd.read_csv(io.BytesIO(uploaded['data_test.txt']), sep=" ", header=None)
#       3 import matplotlib.pyplot as plt
#       4 fig= plt.figure(figsize=(30,7))
#       5 plt.plot(df[0], label='CH 1')
#
# NameError: name 'files' is not defined
